# %%
import spectral.io.envi as envi
import spectral as spy
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image
from scipy import stats
from scipy.stats import lognorm
import statistics
import paramnormal
import pandas as pd
from PIL import Image

# %%
mask_frame = Image.open('/Users/ayasse/Documents/GitHub/spectrometer_masks/output/ang20220618t155027_1/mask.png')
rgb_frame = Image.open('/Users/ayasse/Documents/GitHub/spectrometer_masks/output/ang20220618t155027_1/RGB.png')
cloud_frame = Image.open('/Users/ayasse/Documents/GitHub/spectrometer_masks/output/ang20220618t155027_1/cloud.png')

# %%
np_frame = np.array(mask_frame)
np_cloud = np_frame[:,:,2]-np_frame[:,:,1]+ 255
mask = np.ma.masked_where(np_cloud==255,np_cloud)

np_frame = np.array(rgb_frame)
print(np_frame.shape)
plt.imshow(np_frame[:,:,:])
plt.imshow(mask, cmap='spring', alpha = 0.7)
plt.show()

np_frame = np.array(cloud_frame)
print(np_frame.shape)
plt.imshow(np_frame[:,:,:])
plt.show()
# Out:
# (598, 598, 4)
# (598, 598, 4)

# %%
mask_frame = Image.open('/Users/ayasse/Documents/GitHub/spectrometer_masks/output/ang20220617t202458_2/mask.png')
rgb_frame = Image.open('/Users/ayasse/Documents/GitHub/spectrometer_masks/output/ang20220617t202458_2/RGB.png')
cloud_frame = Image.open('/Users/ayasse/Documents/GitHub/spectrometer_masks/output/ang20220617t202458_2/cloud.png')

# %%
np_frame = np.array(mask_frame)
np_cloud = np_frame[:,:,2]-np_frame[:,:,1]+ 255
mask = np.ma.masked_where(np_cloud==255,np_cloud)

np_frame = np.array(rgb_frame)
print(np_frame.shape)
plt.imshow(np_frame[:,:,:])
plt.imshow(mask, cmap='spring', alpha = 0.5)
plt.show()

np_frame = np.array(cloud_frame)
print(np_frame.shape)
plt.imshow(np_frame[:,:,:])
plt.show()
# Out:
# (598, 598, 4)
# (598, 598, 4)
